# %% [markdown]
# <a href="https://colab.research.google.com/github/OliverZarate/Extracci-n-de-caracter-sticas/blob/main/Actividad_5_(Extracci%C3%B3n_de_Caracter%C3%ADsticas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Actividad 5 (Extracción de Características)
# ##Oliver Zárate Palafox
# ##A01610960

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dec7220b-75ea-4971-a70d-b25c774c8d98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dec7220b-75ea-4971-a70d-b25c774c8d98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_excel('/content/microretailer_mit_lift_lab.xlsx')
df
# Out:
#                                _record_id             _title  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1    c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2    5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3    6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4    6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
# ..                                    ...                ...
# 166  2413f06e-15cc-4a6f-8e83-5224c6824b12   November 3, 2022
# 167  962bf5a6-1eff-4874-a627-9cd8e3ca27b4   November 3, 2022
# 168  9ff658db-4dc5-48b6-aa0b-5c6668bb6720   November 3, 2022
# 169  e88aa9c1-dc8b-4180-99a1-2e0118ad905d   November 3, 2022
# 170  bf720ff0-3b7d-47ed-ba49-f5d4bfb7293c   November 3, 2022
#
#           _server_updated_at           _updated_by  \
# 0    2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1    2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2    2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %%
df.head()
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2  5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3  6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4  6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 3  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 4  2022-11-12 22:15:08 UTC  Salomon Abdala Perez
#
#                                        _geometry  _latitude  _longitude  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
# 2    SRID=4326;POINT(-98.232299887 19.058654656)  19.058655  -98.232300
# ...

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop     73
# 318_shopkeeper_name                     123
# 319_shopkeepers_last_name               125
# 236_whatsapp                            129
# 235_email                               142
# Length: 106, dtype: int64

# %%
df_sin_nulos = df.dropna()

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop     73
# 318_shopkeeper_name                     123
# 319_shopkeepers_last_name               125
# 236_whatsapp                            129
# 235_email                               142
# Length: 106, dtype: int64

# %%
df = df.fillna(method='ffill')
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# _record_id                              0
# _title                                  0
# _server_updated_at                      0
# _updated_by                             0
# _geometry                               0
#                                        ..
# 234_willingness_participate_workshop    0
# 318_shopkeeper_name                     7
# 319_shopkeepers_last_name               7
# 236_whatsapp                            9
# 235_email                               7
# Length: 106, dtype: int64

# %%
df = df.fillna(method='bfill')
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# _record_id                              0
# _title                                  0
# _server_updated_at                      0
# _updated_by                             0
# _geometry                               0
#                                        ..
# 234_willingness_participate_workshop    0
# 318_shopkeeper_name                     0
# 319_shopkeepers_last_name               0
# 236_whatsapp                            0
# 235_email                               0
# Length: 106, dtype: int64

# %%
y=df
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido _latitude                                            1.911117e+01
# _longitude                                          -9.809030e+01
# 97_number_of_customers_in_store                      6.591777e+00
# 268_number_fridges                                   1.020693e+01
# 104_how_many_shelves_does_the_micro_retailer_have    5.581292e+01
# 2_current_permanent_employees                        1.371533e+01
# 4_number_permanent_employees_last_year               1.242350e+01
# 103_number_own_fridges                               8.984091e+00
# 145_number_direct_competitors                        1.382033e+01
# 24_burnout                                           1.037826e+01
# 271_card_fee                                                  NaN
# 272_card_days_receive_money                          3.621305e+00
# 273_platform_extra_charge                                     NaN
# 274_platform_fee                                              NaN
# ...

# %%
df2= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
df2
# Out:
# <ipython-input-42-6c9308265050>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df2= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#     _record_id _title _server_updated_at _updated_by _geometry  _latitude  \
# 0          NaN    NaN                NaN         NaN       NaN  19.053536
# 1          NaN    NaN                NaN         NaN       NaN  19.053561
# 2          NaN    NaN                NaN         NaN       NaN  19.058655
# 3          NaN    NaN                NaN         NaN       NaN  19.059293
# 4          NaN    NaN                NaN         NaN       NaN  19.059585
# ..         ...    ...                ...         ...       ...        ...
# 166        NaN    NaN                NaN         NaN       NaN  19.043115
# 167        NaN    NaN                NaN         NaN       NaN  19.042794
# ...

# %%
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# _record_id                              171
# _title                                  171
# _server_updated_at                      171
# _updated_by                             171
# _geometry                               171
#                                        ...
# 234_willingness_participate_workshop    171
# 318_shopkeeper_name                     171
# 319_shopkeepers_last_name               171
# 236_whatsapp                              3
# 235_email                               171
# Length: 106, dtype: int64

# %%
df3 = df2.dropna(axis=1, how='all')
df3
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                              2.0
# 1    19.053561  -98.234142                              0.0
# 2    19.058655  -98.232300                              0.0
# 3    19.059293  -98.233158                              0.0
# 4    19.059585  -98.233864                              0.0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                              1.0
# 167  19.042794  -98.193802                              1.0
# 168  19.042809  -98.193439                              3.0
# 169  19.042558  -98.193818                              0.0
# 170  19.042823  -98.193735                              1.0
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have  \
# 0                   0.0                                                4.0
# 1                   4.0                                                8.0
# ...

# %%
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# _latitude                                            0
# _longitude                                           0
# 97_number_of_customers_in_store                      4
# 268_number_fridges                                   3
# 104_how_many_shelves_does_the_micro_retailer_have    3
# 2_current_permanent_employees                        1
# 4_number_permanent_employees_last_year               1
# 103_number_own_fridges                               1
# 145_number_direct_competitors                        5
# 24_burnout                                           0
# 272_card_days_receive_money                          3
# 276_expected_days_informal_credit                    6
# 36_credit_default_rate                               6
# 315_frequency_topups                                 3
# 316_frequency_utility_bills                          0
# 317_home_deliveries                                  3
# 62_frequency_only_services                           5
# ...

# %%
data_clean=df3.copy()
data_clean=data_clean.fillna(round(df3.mean(),1))
data_clean
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                              2.0
# 1    19.053561  -98.234142                              0.0
# 2    19.058655  -98.232300                              0.0
# 3    19.059293  -98.233158                              0.0
# 4    19.059585  -98.233864                              0.0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                              1.0
# 167  19.042794  -98.193802                              1.0
# 168  19.042809  -98.193439                              3.0
# 169  19.042558  -98.193818                              0.0
# 170  19.042823  -98.193735                              1.0
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have  \
# 0                   0.0                                                4.0
# 1                   4.0                                                8.0
# ...

# %%
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# _latitude                                            0
# _longitude                                           0
# 97_number_of_customers_in_store                      0
# 268_number_fridges                                   0
# 104_how_many_shelves_does_the_micro_retailer_have    0
# 2_current_permanent_employees                        0
# 4_number_permanent_employees_last_year               0
# 103_number_own_fridges                               0
# 145_number_direct_competitors                        0
# 24_burnout                                           0
# 272_card_days_receive_money                          0
# 276_expected_days_informal_credit                    0
# 36_credit_default_rate                               0
# 315_frequency_topups                                 0
# 316_frequency_utility_bills                          0
# 317_home_deliveries                                  0
# 62_frequency_only_services                           0
# ...

# %%
sns.countplot(x='_latitude', data=data_clean)
plt.title('Análisis univariado de _latitude')
plt.show()

# %%
data = {
    'Variable': ['_latitude'],
    'Media': [data_clean['_latitude'].mean()],
    'Mediana': [data_clean['_latitude'].median()],
    'Desviación Estándar': [data_clean['_latitude'].std()],
    'Mínimo': [data_clean['_latitude'].min()],
    'Máximo': [data_clean['_latitude'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#     Variable      Media    Mediana  Desviación Estándar     Mínimo     Máximo
# 0  _latitude  19.045305  19.043188             0.021956  18.999309  19.075273

# %%
sns.countplot(x='_longitude', data=data_clean)
plt.title('Análisis univariado de _longitude')
plt.show()

# %%
data = {
    'Variable': ['_longitude'],
    'Media': [data_clean['_longitude'].mean()],
    'Mediana': [data_clean['_longitude'].median()],
    'Desviación Estándar': [data_clean['_longitude'].std()],
    'Mínimo': [data_clean['_longitude'].min()],
    'Máximo': [data_clean['_longitude'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#      Variable      Media    Mediana  Desviación Estándar     Mínimo     Máximo
# 0  _longitude -98.218969 -98.217874             0.042889 -98.314273 -98.163314

# %%
sns.countplot(x='97_number_of_customers_in_store', data=data_clean)
plt.title('Análisis univariado de 97_number_of_customers_in_store')
plt.show()

# %%
data = {
    'Variable': ['97_number_of_customers_in_store'],
    'Media': [data_clean['97_number_of_customers_in_store'].mean()],
    'Mediana': [data_clean['97_number_of_customers_in_store'].median()],
    'Desviación Estándar': [data_clean['97_number_of_customers_in_store'].std()],
    'Mínimo': [data_clean['97_number_of_customers_in_store'].min()],
    'Máximo': [data_clean['97_number_of_customers_in_store'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                           Variable     Media  Mediana  Desviación Estándar  \
# 0  97_number_of_customers_in_store  1.221053      1.0             1.325772
#
#    Mínimo  Máximo
# 0     0.0     6.0

# %%
sns.countplot(x='268_number_fridges', data=data_clean)
plt.title('Análisis univariado de 268_number_fridges')
plt.show()
data = {
    'Variable': ['268_number_fridges'],
    'Media': [data_clean['268_number_fridges'].mean()],
    'Mediana': [data_clean['268_number_fridges'].median()],
    'Desviación Estándar': [data_clean['268_number_fridges'].std()],
    'Mínimo': [data_clean['268_number_fridges'].min()],
    'Máximo': [data_clean['268_number_fridges'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#              Variable     Media  Mediana  Desviación Estándar  Mínimo  Máximo
# 0  268_number_fridges  1.363743      1.0             1.816356     0.0     9.0

# %%
sns.countplot(x='104_how_many_shelves_does_the_micro_retailer_have', data=data_clean)
plt.title('Análisis univariado de 104_how_many_shelves_does_the_micro_retailer_have')
plt.show()
data = {
    'Variable': ['104_how_many_shelves_does_the_micro_retailer_have'],
    'Media': [data_clean['104_how_many_shelves_does_the_micro_retailer_have'].mean()],
    'Mediana': [data_clean['104_how_many_shelves_does_the_micro_retailer_have'].median()],
    'Desviación Estándar': [data_clean['104_how_many_shelves_does_the_micro_retailer_have'].std()],
    'Mínimo': [data_clean['104_how_many_shelves_does_the_micro_retailer_have'].min()],
    'Máximo': [data_clean['104_how_many_shelves_does_the_micro_retailer_have'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                                             Variable     Media  Mediana  \
# 0  104_how_many_shelves_does_the_micro_retailer_have  4.714035      3.0
#
#    Desviación Estándar  Mínimo  Máximo
# 0             5.134821     0.0    30.0

# %%
valores_nulos
# Out:
# _latitude                                            0
# _longitude                                           0
# 97_number_of_customers_in_store                      0
# 268_number_fridges                                   0
# 104_how_many_shelves_does_the_micro_retailer_have    0
# 2_current_permanent_employees                        0
# 4_number_permanent_employees_last_year               0
# 103_number_own_fridges                               0
# 145_number_direct_competitors                        0
# 24_burnout                                           0
# 272_card_days_receive_money                          0
# 276_expected_days_informal_credit                    0
# 36_credit_default_rate                               0
# 315_frequency_topups                                 0
# 316_frequency_utility_bills                          0
# 317_home_deliveries                                  0
# 62_frequency_only_services                           0
# ...

# %%
sns.countplot(x='2_current_permanent_employees', data=data_clean)
plt.title('Análisis univariado de 2_current_permanent_employees')
plt.show()
data = {
    'Variable': ['2_current_permanent_employees'],
    'Media': [data_clean['2_current_permanent_employees'].mean()],
    'Mediana': [data_clean['2_current_permanent_employees'].median()],
    'Desviación Estándar': [data_clean['2_current_permanent_employees'].std()],
    'Mínimo': [data_clean['2_current_permanent_employees'].min()],
    'Máximo': [data_clean['2_current_permanent_employees'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                         Variable     Media  Mediana  Desviación Estándar  \
# 0  2_current_permanent_employees  1.546784      1.0             1.401943
#
#    Mínimo  Máximo
# 0     0.0     6.0

# %%
sns.countplot(x='4_number_permanent_employees_last_year', data=data_clean)
plt.title('Análisis univariado de 4_number_permanent_employees_last_year')
plt.show()
data = {
    'Variable': ['4_number_permanent_employees_last_year'],
    'Media': [data_clean['4_number_permanent_employees_last_year'].mean()],
    'Mediana': [data_clean['4_number_permanent_employees_last_year'].median()],
    'Desviación Estándar': [data_clean['4_number_permanent_employees_last_year'].std()],
    'Mínimo': [data_clean['4_number_permanent_employees_last_year'].min()],
    'Máximo': [data_clean['4_number_permanent_employees_last_year'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                                  Variable     Media  Mediana  \
# 0  4_number_permanent_employees_last_year  1.382456      1.0
#
#    Desviación Estándar  Mínimo  Máximo
# 0             1.341964     0.0     6.0

# %%
sns.countplot(x='103_number_own_fridges', data=data_clean)
plt.title('Análisis univariado de 103_number_own_fridges')
plt.show()
data = {
    'Variable': ['103_number_own_fridges'],
    'Media': [data_clean['103_number_own_fridges'].mean()],
    'Mediana': [data_clean['103_number_own_fridges'].median()],
    'Desviación Estándar': [data_clean['103_number_own_fridges'].std()],
    'Mínimo': [data_clean['103_number_own_fridges'].min()],
    'Máximo': [data_clean['103_number_own_fridges'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                  Variable     Media  Mediana  Desviación Estándar  Mínimo  \
# 0  103_number_own_fridges  1.994152      2.0             1.835907     0.0
#
#    Máximo
# 0     7.0

# %%
sns.countplot(x='145_number_direct_competitors', data=data_clean)
plt.title('Análisis univariado de 145_number_direct_competitors')
plt.show()
data = {
    'Variable': ['145_number_direct_competitors'],
    'Media': [data_clean['145_number_direct_competitors'].mean()],
    'Mediana': [data_clean['145_number_direct_competitors'].median()],
    'Desviación Estándar': [data_clean['145_number_direct_competitors'].std()],
    'Mínimo': [data_clean['145_number_direct_competitors'].min()],
    'Máximo': [data_clean['145_number_direct_competitors'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                         Variable     Media  Mediana  Desviación Estándar  \
# 0  145_number_direct_competitors  3.295322      3.0             2.418721
#
#    Mínimo  Máximo
# 0     0.0    10.0

# %%
sns.countplot(x='24_burnout', data=data_clean)
plt.title('Análisis univariado de 24_burnout')
plt.show()
data = {
    'Variable': ['24_burnout'],
    'Media': [data_clean['24_burnout'].mean()],
    'Mediana': [data_clean['24_burnout'].median()],
    'Desviación Estándar': [data_clean['24_burnout'].std()],
    'Mínimo': [data_clean['24_burnout'].min()],
    'Máximo': [data_clean['24_burnout'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#      Variable     Media  Mediana  Desviación Estándar  Mínimo  Máximo
# 0  24_burnout  4.181287      4.0             2.065658     1.0     7.0

# %%
sns.countplot(x='272_card_days_receive_money', data=data_clean)
plt.title('Análisis univariado de 272_card_days_receive_money')
plt.show()
data = {
    'Variable': ['272_card_days_receive_money'],
    'Media': [data_clean['272_card_days_receive_money'].mean()],
    'Mediana': [data_clean['272_card_days_receive_money'].median()],
    'Desviación Estándar': [data_clean['272_card_days_receive_money'].std()],
    'Mínimo': [data_clean['272_card_days_receive_money'].min()],
    'Máximo': [data_clean['272_card_days_receive_money'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                       Variable     Media  Mediana  Desviación Estándar  \
# 0  272_card_days_receive_money  0.661404      1.0             0.773325
#
#    Mínimo  Máximo
# 0     0.0     3.0

# %%
sns.countplot(x='276_expected_days_informal_credit', data=data_clean)
plt.title('Análisis univariado de 276_expected_days_informal_credit')
plt.show()
data = {
    'Variable': ['276_expected_days_informal_credit'],
    'Media': [data_clean['276_expected_days_informal_credit'].mean()],
    'Mediana': [data_clean['276_expected_days_informal_credit'].median()],
    'Desviación Estándar': [data_clean['276_expected_days_informal_credit'].std()],
    'Mínimo': [data_clean['276_expected_days_informal_credit'].min()],
    'Máximo': [data_clean['276_expected_days_informal_credit'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                             Variable     Media  Mediana  Desviación Estándar  \
# 0  276_expected_days_informal_credit  7.435088      3.0             8.926691
#
#    Mínimo  Máximo
# 0     1.0    30.0

# %%
sns.countplot(x='36_credit_default_rate', data=data_clean)
plt.title('Análisis univariado de 36_credit_default_rate')
plt.show()
data = {
    'Variable': ['36_credit_default_rate'],
    'Media': [data_clean['36_credit_default_rate'].mean()],
    'Mediana': [data_clean['36_credit_default_rate'].median()],
    'Desviación Estándar': [data_clean['36_credit_default_rate'].std()],
    'Mínimo': [data_clean['36_credit_default_rate'].min()],
    'Máximo': [data_clean['36_credit_default_rate'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                  Variable     Media  Mediana  Desviación Estándar  Mínimo  \
# 0  36_credit_default_rate  0.908772      0.9             1.211797     0.0
#
#    Máximo
# 0     5.0

# %%
sns.countplot(x='315_frequency_topups', data=data_clean)
plt.title('Análisis univariado de 315_frequency_topups')
plt.show()
data = {
    'Variable': ['315_frequency_topups'],
    'Media': [data_clean['315_frequency_topups'].mean()],
    'Mediana': [data_clean['315_frequency_topups'].median()],
    'Desviación Estándar': [data_clean['315_frequency_topups'].std()],
    'Mínimo': [data_clean['315_frequency_topups'].min()],
    'Máximo': [data_clean['315_frequency_topups'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                Variable     Media  Mediana  Desviación Estándar  Mínimo  \
# 0  315_frequency_topups  4.887135      7.0             2.852091     0.0
#
#    Máximo
# 0     7.0

# %%
valores_nulos
# Out:
# _latitude                                            0
# _longitude                                           0
# 97_number_of_customers_in_store                      0
# 268_number_fridges                                   0
# 104_how_many_shelves_does_the_micro_retailer_have    0
# 2_current_permanent_employees                        0
# 4_number_permanent_employees_last_year               0
# 103_number_own_fridges                               0
# 145_number_direct_competitors                        0
# 24_burnout                                           0
# 272_card_days_receive_money                          0
# 276_expected_days_informal_credit                    0
# 36_credit_default_rate                               0
# 315_frequency_topups                                 0
# 316_frequency_utility_bills                          0
# 317_home_deliveries                                  0
# 62_frequency_only_services                           0
# ...

# %%
sns.countplot(x='316_frequency_utility_bills', data=data_clean)
plt.title('Análisis univariado de 316_frequency_utility_bills')
plt.show()
data = {
    'Variable': ['316_frequency_utility_bills'],
    'Media': [data_clean['316_frequency_utility_bills'].mean()],
    'Mediana': [data_clean['316_frequency_utility_bills'].median()],
    'Desviación Estándar': [data_clean['316_frequency_utility_bills'].std()],
    'Mínimo': [data_clean['316_frequency_utility_bills'].min()],
    'Máximo': [data_clean['316_frequency_utility_bills'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                       Variable      Media  Mediana  Desviación Estándar  \
# 0  316_frequency_utility_bills  36.923977     50.0             19.83906
#
#    Mínimo  Máximo
# 0     7.0    50.0

# %%
sns.countplot(x='317_home_deliveries', data=data_clean)
plt.title('Análisis univariado de 317_home_deliveries')
plt.show()
data = {
    'Variable': ['317_home_deliveries'],
    'Media': [data_clean['317_home_deliveries'].mean()],
    'Mediana': [data_clean['317_home_deliveries'].median()],
    'Desviación Estándar': [data_clean['317_home_deliveries'].std()],
    'Mínimo': [data_clean['317_home_deliveries'].min()],
    'Máximo': [data_clean['317_home_deliveries'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#               Variable     Media  Mediana  Desviación Estándar  Mínimo  Máximo
# 0  317_home_deliveries  8.803509      2.0            12.005028     0.0    40.0

# %%
sns.countplot(x='62_frequency_only_services', data=data_clean)
plt.title('Análisis univariado de 62_frequency_only_services')
plt.show()
data = {
    'Variable': ['62_frequency_only_services'],
    'Media': [data_clean['62_frequency_only_services'].mean()],
    'Mediana': [data_clean['62_frequency_only_services'].median()],
    'Desviación Estándar': [data_clean['62_frequency_only_services'].std()],
    'Mínimo': [data_clean['62_frequency_only_services'].min()],
    'Máximo': [data_clean['62_frequency_only_services'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                      Variable     Media  Mediana  Desviación Estándar  Mínimo  \
# 0  62_frequency_only_services  2.511696      2.0             5.284537     0.0
#
#    Máximo
# 0    35.0

# %%
sns.countplot(x='78_number_home_deliveries_week', data=data_clean)
plt.title('Análisis univariado de 78_number_home_deliveries_week')
plt.show()
data = {
    'Variable': ['78_number_home_deliveries_week'],
    'Media': [data_clean['78_number_home_deliveries_week'].mean()],
    'Mediana': [data_clean['78_number_home_deliveries_week'].median()],
    'Desviación Estándar': [data_clean['78_number_home_deliveries_week'].std()],
    'Mínimo': [data_clean['78_number_home_deliveries_week'].min()],
    'Máximo': [data_clean['78_number_home_deliveries_week'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                          Variable  Media  Mediana  Desviación Estándar  \
# 0  78_number_home_deliveries_week    3.0      3.0                  0.0
#
#    Mínimo  Máximo
# 0     3.0     3.0

# %%
sns.countplot(x='172_supplier_frequency', data=data_clean)
plt.title('Análisis univariado de 172_supplier_frequency')
plt.show()
data = {
    'Variable': ['172_supplier_frequency'],
    'Media': [data_clean['172_supplier_frequency'].mean()],
    'Mediana': [data_clean['172_supplier_frequency'].median()],
    'Desviación Estándar': [data_clean['172_supplier_frequency'].std()],
    'Mínimo': [data_clean['172_supplier_frequency'].min()],
    'Máximo': [data_clean['172_supplier_frequency'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                  Variable     Media  Mediana  Desviación Estándar  Mínimo  \
# 0  172_supplier_frequency  3.292398      2.0             2.517445     1.0
#
#    Máximo
# 0     7.0

# %%
sns.countplot(x='163_number_high_perishable_products', data=data_clean)
plt.title('Análisis univariado de 163_number_high_perishable_products')
plt.show()
data = {
    'Variable': ['163_number_high_perishable_products'],
    'Media': [data_clean['163_number_high_perishable_products'].mean()],
    'Mediana': [data_clean['163_number_high_perishable_products'].median()],
    'Desviación Estándar': [data_clean['163_number_high_perishable_products'].std()],
    'Mínimo': [data_clean['163_number_high_perishable_products'].min()],
    'Máximo': [data_clean['163_number_high_perishable_products'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#                               Variable     Media  Mediana  \
# 0  163_number_high_perishable_products  6.706433      2.0
#
#    Desviación Estándar  Mínimo  Máximo
# 0             8.975989     0.0    40.0

# %%
sns.countplot(x='236_whatsapp', data=data_clean)
plt.title('Análisis univariado de 236_whatsapp')
plt.show()
data = {
    'Variable': ['236_whatsapp'],
    'Media': [data_clean['236_whatsapp'].mean()],
    'Mediana': [data_clean['236_whatsapp'].median()],
    'Desviación Estándar': [data_clean['236_whatsapp'].std()],
    'Mínimo': [data_clean['236_whatsapp'].min()],
    'Máximo': [data_clean['236_whatsapp'].max()],
}
tabla_resumen = pd.DataFrame(data)

print(tabla_resumen)
# Out:
#        Variable         Media       Mediana  Desviación Estándar       Mínimo  \
# 0  236_whatsapp  2.517175e+09  2.225362e+09         9.040655e+08  222230377.0
#
#          Máximo
# 0  5.621770e+09
